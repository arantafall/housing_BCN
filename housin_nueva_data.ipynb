# %%
# !git clone https://github.com/arantafall/housing_BCN.git
# Out:
# Cloning into 'housing_BCN'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 90 (delta 46), reused 70 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 864.23 KiB | 3.17 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
cd housing_BCN
# Out:
# /content/housing_BCN

# %%
cat dataframe.ipynb
# Out:
# cat: dataframe.ipynb: No such file or directory

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/Barcelona_Fotocasa_HousingPrices.csv")

# %%
# !git config --global user.name Arantafall
# !git config --global user.email aran.tafall.campusimpelia@gmail.com

# %%
data.shape
# Out:
# (8188, 10)

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   real_state     neighborhood  square_meters_price
# 0       flat  Horta- Guinardo            12.500000
# 1       flat      Sant Andreu            13.050847
# 2       flat           Gràcia            43.333333
# 3       flat     Ciutat Vella            40.000000
# 4       flat      Sant Andreu            16.363636

# %%
# !git checkout -b aran
# Out:
# Switched to a new branch 'aran'

# %%
# !git branch
# Out:
# * aran
#   main

# %%
data.isnull().sum()
(data.isnull().sum() / len(data)) * 100
# Out:
# Unnamed: 0             0.000000
# price                  0.000000
# rooms                  0.000000
# bathroom               0.000000
# lift                   0.000000
# terrace                0.000000
# square_meters          0.000000
# real_state             3.273083
# neighborhood           0.000000
# square_meters_price    0.000000
# dtype: float64

# %%
data.describe().round(2)
# Out:
#        Unnamed: 0     price    rooms  bathroom  square_meters  \
# count     8188.00   8188.00  8188.00   8188.00        8188.00
# mean      4093.50   1444.09     2.42      1.51          84.61
# std       2363.82   1125.89     1.14      0.73          47.87
# min          0.00    320.00     0.00      1.00          10.00
# 25%       2046.75    875.00     2.00      1.00          56.00
# 50%       4093.50   1100.00     2.00      1.00          73.00
# 75%       6140.25   1540.00     3.00      2.00          95.00
# max       8187.00  15000.00    10.00      8.00         679.00
#
#        square_meters_price
# count              8188.00
# mean                 17.74
# std                   9.25
# min                   4.91
# 25%                  12.79
# 50%                  15.31
# 75%                  19.44
# max                 186.67

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8188 entries, 0 to 8187
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           8188 non-null   int64
#  1   price                8188 non-null   int64
#  2   rooms                8188 non-null   int64
#  3   bathroom             8188 non-null   int64
#  4   lift                 8188 non-null   bool
#  5   terrace              8188 non-null   bool
#  6   square_meters        8188 non-null   int64
#  7   real_state           7920 non-null   object
#  8   neighborhood         8188 non-null   object
#  9   square_meters_price  8188 non-null   float64
# dtypes: bool(2), float64(1), int64(5), object(2)
# memory usage: 527.9+ KB

# %%
data.rename(columns={'real_state': 'property_type'}, inplace=True)

# %%
data['property_type'].unique()
# Out:
# array(['flat', 'attic', nan, 'apartment', 'study'], dtype=object)

# %%
data
# Out:
#       Unnamed: 0  price  rooms  bathroom   lift  terrace  square_meters  \
# 0              0    750      3         1   True    False             60
# 1              1    770      2         1   True    False             59
# 2              2   1300      1         1   True     True             30
# 3              3   2800      1         1   True     True             70
# 4              4    720      2         1   True    False             44
# ...          ...    ...    ...       ...    ...      ...            ...
# 8183        8183   1075      2         2  False    False             65
# 8184        8184   1500      3         2   True    False            110
# 8185        8185   1500      2         2   True     True             90
# 8186        8186   1500      3         2   True    False            110
# 8187        8187   1500      3         2   True    False            110
#
#      property_type         neighborhood  square_meters_price
# ...

# %%
print(data['property_type'].unique())
print(data['property_type'].dtype)
# Out:
# ['flat' 'attic' nan 'apartment' 'study']
# object

# %%
data['property_type'].value_counts()
# Out:
# property_type
# flat         6505
# apartment     991
# attic         315
# study         109
# Name: count, dtype: int64

# %%
data = data.dropna(subset=['property_type'])
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#       Unnamed: 0  price  rooms  bathroom   lift  terrace  square_meters  \
# 0              0    750      3         1   True    False             60
# 1              1    770      2         1   True    False             59
# 2              2   1300      1         1   True     True             30
# 3              3   2800      1         1   True     True             70
# 4              4    720      2         1   True    False             44
# ...          ...    ...    ...       ...    ...      ...            ...
# 7915        8183   1075      2         2  False    False             65
# 7916        8184   1500      3         2   True    False            110
# 7917        8185   1500      2         2   True     True             90
# 7918        8186   1500      3         2   True    False            110
# 7919        8187   1500      3         2   True    False            110
#
#      property_type         neighborhood  square_meters_price
# ...

# %%
# !git add .

# %%
# !git commit -m 'las filas con valor nulo en la columna real_state fueron eliminadas y cambio de nombre de esta columna a property_type'
# Out:
# On branch aran
# nothing to commit, working tree clean

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !git pull origin main
# Out:
# From https://github.com/arantafall/housing_BCN
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git merge aran
# Out:
# Already up to date.

# %%
# !git push https://Arantafall:@github.com/Arantafall/https://github.com/arantafall/housing_BCN.git/
# Out:
# remote: Not Found
# fatal: repository 'https://github.com/Arantafall/https://github.com/arantafall/housing_BCN.git/' not found

# %%
# !git push https://Arantafall:@github.com/Arantafall/housing_BCN.git
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/Arantafall/housing_BCN.git/'

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
data.describe()
# Out:
#         Unnamed: 0         price        rooms     bathroom  square_meters  \
# count  7920.000000   7920.000000  7920.000000  7920.000000    7920.000000
# mean   4102.152399   1434.894949     2.444066     1.504672      84.538636
# std    2362.481061   1119.528321     1.125266     0.728770      47.584487
# min       0.000000    320.000000     0.000000     1.000000      10.000000
# 25%    2052.750000    875.000000     2.000000     1.000000      56.000000
# 50%    4098.500000   1100.000000     2.000000     1.000000      73.000000
# 75%    6155.250000   1500.000000     3.000000     2.000000      95.000000
# max    8187.000000  15000.000000    10.000000     8.000000     679.000000
#
#        square_meters_price
# count          7920.000000
# mean             17.625957
# std               9.015493
# min               5.555556
# 25%              12.777778
# 50%              15.217391
# 75%              19.298246
# max             185.000000

# %%
data["price"].describe()
# Out:
# count     7920.000000
# mean      1434.894949
# std       1119.528321
# min        320.000000
# 25%        875.000000
# 50%       1100.000000
# 75%       1500.000000
# max      15000.000000
# Name: price, dtype: float64

# %%
 data["square_meters"].describe()
# Out:
# count    7920.000000
# mean       84.538636
# std        47.584487
# min        10.000000
# 25%        56.000000
# 50%        73.000000
# 75%        95.000000
# max       679.000000
# Name: square_meters, dtype: float64

# %%
data["rooms"].describe()
# Out:
# count    7920.000000
# mean        2.444066
# std         1.125266
# min         0.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        10.000000
# Name: rooms, dtype: float64

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
data[["neighborhood","square_meters"]].describe()
# Out:
#        square_meters
# count    7920.000000
# mean       84.538636
# std        47.584487
# min        10.000000
# 25%        56.000000
# 50%        73.000000
# 75%        95.000000
# max       679.000000

# %%
data.terrace.describe()
# Out:
# count      7920
# unique        2
# top       False
# freq       6294
# Name: terrace, dtype: object

# %%
data.terrace.value_counts()
# Out:
# terrace
# False    6294
# True     1626
# Name: count, dtype: int64

# %%
print(data[['square_meters_price', 'neighborhood']].describe())
# Out:
#        square_meters_price
# count          7920.000000
# mean             17.625957
# std               9.015493
# min               5.555556
# 25%              12.777778
# 50%              15.217391
# 75%              19.298246
# max             185.000000

# %%
print(data['neighborhood'].value_counts())
# Out:
# neighborhood
# Eixample               2360
# Sarria-Sant Gervasi    1320
# Ciutat Vella           1314
# Gràcia                  658
# Sant Martí              592
# Sants-Montjuïc          572
# Les Corts               512
# Horta- Guinardo         305
# Sant Andreu             174
# Nou Barris              113
# Name: count, dtype: int64

# %%
data['square_meters_price'].describe();
data['neighborhood'].describe()
# Out:
# count         7920
# unique          10
# top       Eixample
# freq          2360
# Name: neighborhood, dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
data['square_meters_price'] > 1000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7915    False
# 7916    False
# 7917    False
# 7918    False
# 7919    False
# Name: square_meters_price, Length: 7920, dtype: bool

# %%
#Precio por metro cuadrado depeniendo del barrio
grouped_stats = data.groupby('neighborhood')['square_meters_price'].mean()
(grouped_stats)
# Out:
# neighborhood
# Ciutat Vella           19.032033
# Eixample               18.943313
# Gràcia                 16.897971
# Horta- Guinardo        13.564087
# Les Corts              15.806625
# Nou Barris             12.440466
# Sant Andreu            13.146563
# Sant Martí             17.833465
# Sants-Montjuïc         16.443467
# Sarria-Sant Gervasi    17.331831
# Name: square_meters_price, dtype: float64

# %%
#Precio por m2 dependiendo del  barrio
price_stats = data.groupby('neighborhood')['square_meters_price'].agg(['mean', 'min', 'max', 'median']).round(2)
(price_stats)
# Out:
#                       mean   min     max  median
# neighborhood
# Ciutat Vella         19.03  6.57  185.00   17.00
# Eixample             18.94  6.74  144.50   15.59
# Gràcia               16.90  7.00   92.50   14.62
# Horta- Guinardo      13.56  7.16   37.67   12.73
# Les Corts            15.81  8.12   47.06   14.71
# Nou Barris           12.44  8.77   25.38   12.50
# Sant Andreu          13.15  7.00   42.86   12.50
# Sant Martí           17.83  8.09   75.36   15.23
# Sants-Montjuïc       16.44  8.62  100.00   14.21
# Sarria-Sant Gervasi  17.33  5.56   48.43   15.92

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
price_per_room = data.groupby('rooms')['square_meters_price'].mean().round(2)
(price_per_room)
# Out:
# rooms
# 0     18.34
# 1     21.71
# 2     18.43
# 3     15.65
# 4     14.72
# 5     15.54
# 6     14.90
# 7     10.95
# 9     10.13
# 10    18.42
# Name: square_meters_price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
price_by_features = data.groupby('lift')['square_meters_price'].mean()
(price_by_features)
# Out:
# lift
# False    20.328323
# True     16.443979
# Name: square_meters_price, dtype: float64

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
data.head()
# Out:
#    Unnamed: 0  price  rooms  bathroom  lift  terrace  square_meters  \
# 0           0    750      3         1  True    False             60
# 1           1    770      2         1  True    False             59
# 2           2   1300      1         1  True     True             30
# 3           3   2800      1         1  True     True             70
# 4           4    720      2         1  True    False             44
#
#   property_type     neighborhood  square_meters_price
# 0          flat  Horta- Guinardo            12.500000
# 1          flat      Sant Andreu            13.050847
# 2          flat           Gràcia            43.333333
# 3          flat     Ciutat Vella            40.000000
# 4          flat      Sant Andreu            16.363636

# %%
#Anlasi aument de precios dependiendo de numero de baños
variacion = data.groupby(['neighborhood', 'bathroom'])['price'].mean().reset_index(). round(2)
(variacion)
# Out:
#            neighborhood  bathroom    price
# 0          Ciutat Vella         1  1027.91
# 1          Ciutat Vella         2  1635.34
# 2          Ciutat Vella         3  2344.86
# 3          Ciutat Vella         4  2666.67
# 4              Eixample         1  1199.97
# 5              Eixample         2  1791.65
# 6              Eixample         3  3013.35
# 7              Eixample         4  3801.80
# 8              Eixample         5  4461.67
# 9              Eixample         6  7700.00
# 10             Eixample         8  1995.00
# 11               Gràcia         1  1017.33
# 12               Gràcia         2  1400.71
# 13               Gràcia         3  2506.67
# 14               Gràcia         4  1900.00
# 15      Horta- Guinardo         1   833.83
# 16      Horta- Guinardo         2  1102.94
# 17      Horta- Guinardo         3  1928.00
# 18      Horta- Guinardo         4  3600.00
# 19            Les Corts         1  1052.31
# 20            Les Corts         2  1542.33
# ...

# %%
#Anlasi aument de precios dependiendo de numero de habitaciones
variacion = data.groupby(['neighborhood', 'rooms'])['price'].mean().reset_index(). round(2)
(variacion)
# Out:
#            neighborhood  rooms    price
# 0          Ciutat Vella      0   984.77
# 1          Ciutat Vella      1   992.18
# 2          Ciutat Vella      2  1249.37
# 3          Ciutat Vella      3  1536.88
# 4          Ciutat Vella      4  1664.73
# ..                  ...    ...      ...
# 63  Sarria-Sant Gervasi      3  1716.31
# 64  Sarria-Sant Gervasi      4  2964.68
# 65  Sarria-Sant Gervasi      5  3503.16
# 66  Sarria-Sant Gervasi      6  3982.57
# 67  Sarria-Sant Gervasi     10  7000.00
#
# [68 rows x 3 columns]

# %%
#Anlasi aument de precios dependiendo de si tiene  acensor o no

variacion = data.groupby(['neighborhood', 'lift'])['price'].mean().reset_index(). round(2)
(variacion)
# Out:
#            neighborhood   lift    price
# 0          Ciutat Vella  False  1101.53
# 1          Ciutat Vella   True  1349.09
# 2              Eixample  False  2005.60
# 3              Eixample   True  1466.32
# 4                Gràcia  False  1156.89
# 5                Gràcia   True  1126.43
# 6       Horta- Guinardo  False   856.02
# 7       Horta- Guinardo   True   946.96
# 8             Les Corts  False  1271.47
# 9             Les Corts   True  1674.73
# 10           Nou Barris  False   753.00
# 11           Nou Barris   True   843.78
# 12          Sant Andreu  False   885.91
# 13          Sant Andreu   True   896.23
# 14           Sant Martí  False  1424.99
# 15           Sant Martí   True  1445.25
# 16       Sants-Montjuïc  False  1098.75
# 17       Sants-Montjuïc   True   984.73
# 18  Sarria-Sant Gervasi  False  1549.24
# 19  Sarria-Sant Gervasi   True  1946.41

# %%
#Anlasi aument de precios dependiendo de si tiene  terraza o no
variacion = data.groupby(['neighborhood', 'terrace'])['price'].mean().reset_index(). round(2)
(variacion)
# Out:
#            neighborhood  terrace    price
# 0          Ciutat Vella    False  1158.92
# 1          Ciutat Vella     True  1551.34
# 2              Eixample    False  1535.77
# 3              Eixample     True  1792.03
# 4                Gràcia    False  1105.47
# 5                Gràcia     True  1263.94
# 6       Horta- Guinardo    False   867.00
# 7       Horta- Guinardo     True  1051.82
# 8             Les Corts    False  1402.73
# 9             Les Corts     True  2105.41
# 10           Nou Barris    False   802.73
# 11           Nou Barris     True   834.95
# 12          Sant Andreu    False   880.41
# 13          Sant Andreu     True   949.76
# 14           Sant Martí    False  1288.70
# 15           Sant Martí     True  1924.88
# 16       Sants-Montjuïc    False  1033.21
# 17       Sants-Montjuïc     True  1034.18
# 18  Sarria-Sant Gervasi    False  1658.33
# 19  Sarria-Sant Gervasi     True  2530.99

# %%
#Precio promedio y distribución de precios por barrio
price_stats = data.groupby('neighborhood')['price'].agg(['mean', 'min', 'max', 'median']).round(2)
(price_stats)
# Out:
#                         mean  min    max  median
# neighborhood
# Ciutat Vella         1211.18  450  14800   995.0
# Eixample             1585.83  490  15000  1225.0
# Gràcia               1138.47  423   6000   977.5
# Horta- Guinardo       907.60  484   3600   825.0
# Les Corts            1614.09  550   8500  1213.5
# Nou Barris            808.43  550   1650   780.0
# Sant Andreu           893.56  480   1500   850.0
# Sant Martí           1440.22  380  12000  1000.0
# Sants-Montjuïc       1033.37  320   5476   900.0
# Sarria-Sant Gervasi  1884.43  545  15000  1350.0

# %%
# identificación de barrios con viviendas con las mejores o peores características en relación calidad-precio
